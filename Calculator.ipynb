# %%
num1=input('Enter First Number')
num2=input('Enter Second Number')
sum1=int(num1)+int(num2)
print('The Sum is: {0} ',format(sum1))
# Out:
# Enter First Number 3
# Enter Second Number 4
# The Sum is: {0}  7
